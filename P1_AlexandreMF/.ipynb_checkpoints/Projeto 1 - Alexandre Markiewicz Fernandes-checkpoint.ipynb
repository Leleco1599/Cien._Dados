# %% [markdown]
# # Há  aumento do IDH em países com mais computadores? E com usuários de internet?

# %% [markdown]
# ### Nota-se que, desde o início do século XXI, artificíos tecnológicos começaram a nos servir cada vez mais no cotidiano. De fato, atualmente é raro se deparar com alguém que não esteja envolvido em algum tipo de rede social e internet. O fluxo de informação partiu de ser algo local para algo global.
# ### Diante disso, cabe descobrir se a partir de uma maior disposição de conteúdo, notícias de todos os lugares do mundo e acesso à conhecimento, as pessoas se tornam mais desenvolvidas.

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import os
meu_diretorio = "/Users/Alexandre Markiewicz/Documents/Insper/2 SEMESTRE/Cien. Dados/P1_AlexandreMF"
os.chdir(meu_diretorio)

# %%
df_internet = pd.read_excel("Internet user total.xlsx")
df_IDH = pd.read_excel("Indicator_HDI.xlsx")
df_computers = pd.read_excel("indicator Personal computers (ITU estimates_MDG) .xls.xlsx")
df_IDH
# Out:
#                            HDI   1980   1990   2000   2005   2006   2007  \
# 0                     Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN
# 1                  Afghanistan  0.198  0.246  0.230  0.340  0.354  0.363
# 2        Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN
# 3                      Albania    NaN  0.656  0.691  0.721  0.724  0.729
# 4                      Algeria  0.454  0.551  0.624  0.667  0.673  0.680
# 5               American Samoa    NaN    NaN    NaN    NaN    NaN    NaN
# 6                      Andorra    NaN    NaN    NaN    NaN    NaN    NaN
# 7                       Angola    NaN    NaN  0.384  0.445  0.459  0.471
# 8                     Anguilla    NaN    NaN    NaN    NaN    NaN    NaN
# 9          Antigua and Barbuda    NaN    NaN    NaN    NaN    NaN    NaN
# 10                   Argentina  0.669  0.697  0.749  0.765  0.773  0.780
# 11                     Armenia    NaN    NaN  0.643  0.689  0.703  0.715
# 12                       Aruba    NaN    NaN    NaN    NaN    NaN    NaN
# 13                   Australia  0.850  0.873  0.906  0.918  0.920  0.922
# 14                     Austria  0.740  0.790  0.839  0.860  0.866  0.870
# 15                  Azerbaijan    NaN    NaN    NaN    NaN    NaN    NaN
# 16                     Bahamas    NaN    NaN  0.752  0.766  0.768  0.770
# 17                     Bahrain  0.651  0.721  0.773  0.795  0.799  0.804
# 18                  Bangladesh  0.303  0.352  0.422  0.462  0.470  0.478
# 19                    Barbados    NaN    NaN    NaN  0.787  0.790  0.791
# 20                     Belarus    NaN    NaN    NaN  0.723  0.731  0.738
# 21                     Belgium  0.757  0.811  0.876  0.873  0.877  0.880
# 22                      Belize  0.619  0.651  0.668  0.689  0.690  0.692
# 23                       Benin  0.252  0.316  0.378  0.409  0.411  0.414
# 24                     Bermuda    NaN    NaN    NaN    NaN    NaN    NaN
# 25                      Bhutan    NaN    NaN    NaN    NaN    NaN    NaN
# 26                     Bolivia  0.507  0.560  0.612  0.649  0.650  0.645
# 27      Bosnia and Herzegovina    NaN    NaN    NaN  0.717  0.720  0.725
# 28                    Botswana  0.446  0.594  0.585  0.601  0.611  0.618
# 29                      Brazil  0.549  0.600  0.665  0.692  0.695  0.700
# ..                         ...    ...    ...    ...    ...    ...    ...
# 240              United States  0.837  0.870  0.897  0.902  0.904  0.905
# 28   0.624  0.626  0.633
# 29   0.705  0.708  0.718
# ..     ...    ...    ...
# 240  0.907  0.906  0.910
# 241  0.769  0.773  0.783
# 242    NaN    NaN    NaN
# 243  0.624  0.631  0.641
# 244    NaN    NaN    NaN
# 245    NaN    NaN  0.617
# 246  0.730  0.732  0.735
# 247    NaN    NaN  0.641
# 248    NaN    NaN    NaN
# 249    NaN    NaN    NaN
# 250  0.580  0.584  0.593
# 251    NaN    NaN    NaN
# 252    NaN    NaN    NaN
# 253    NaN    NaN    NaN
# 254  0.444  0.452  0.462
# 255    NaN    NaN    NaN
# 256  0.413  0.419  0.430
# 257  0.338  0.349  0.376
# 258    NaN    NaN    NaN
# 259    NaN    NaN    NaN
# 260    NaN    NaN    NaN
# 261    NaN    NaN    NaN
# 262    NaN    NaN    NaN
# 263    NaN    NaN    NaN
# 264    NaN    NaN    NaN
# 265    NaN    NaN    NaN
# 266    NaN    NaN    NaN
# 267    NaN    NaN    NaN
# 268    NaN    NaN    NaN
# 269    NaN    NaN    NaN
#
# [270 rows x 10 columns]

# %%
#======== 2000 =========
internet_2000 = df_internet.loc[:,["Internet users, total number","2000"]]
IDH_2000 = df_IDH.loc[:,["HDI",2000]]
computers_2000 = df_computers.loc[:,["Personal computers",2000]]


#======== 2005 =========
internet_2005 = df_internet.loc[:,["Internet users, total number","2005"]]
IDH_2005 = df_IDH.loc[:,["HDI",2005]]
computers_2005 = df_computers.loc[:,["Personal computers",2005]]

# %%
int_indx = internet_2000.set_index("Internet users, total number")
IDH_indx = IDH_2000.set_index("HDI")
comp_indx = computers_2000.set_index("Personal computers")


int_indx05 = internet_2005.set_index("Internet users, total number")
IDH_indx05 = IDH_2005.set_index("HDI")
comp_indx05 = computers_2005.set_index("Personal computers")

# %%
data_1 = int_indx.join(IDH_indx, how='inner', lsuffix='_Internet Users', rsuffix='_IDH')
data_2 = comp_indx.join(data_1, how='inner', lsuffix='_PCs', rsuffix='_IDH')


data_1_05 = int_indx05.join(IDH_indx05, how='inner', lsuffix='_Internet Users', rsuffix='_IDH')
data_2_05 = comp_indx05.join(data_1_05, how='inner', lsuffix='_PCs', rsuffix='_IDH')

datajoin = data_2.join(data_2_05, how= 'inner', lsuffix='_PCs', rsuffix='_IDH')
data.dropna(inplace=True)
datajoin
#data
# Out:
#                            2000_PCs          2000  2000_IDH     2005_PCs  \
# Afghanistan                     NaN           NaN     0.230      85000.0
# Albania                     25000.0  3.504906e+03     0.691      54000.0
# Algeria                    200000.0  1.501366e+05     0.624     350000.0
# Angola                      15000.0  1.462904e+04     0.384      93396.0
# Antigua and Barbuda             NaN  5.033837e+03       NaN      12100.0
# Argentina                 2560000.0  2.599436e+06     0.749    3500000.0
# Armenia                     25000.0  4.000373e+04     0.643     297000.0
# Aruba                           NaN  1.394039e+04       NaN       7926.0
# Australia                 9000000.0  8.960506e+06     0.906          NaN
# Austria                   2900000.0  2.700000e+06     0.839    4996000.0
# Azerbaijan                      NaN  1.198421e+04       NaN     194700.0
#
#                                 2005  2005_IDH
# Afghanistan             3.380450e+05     0.340
# Albania                 1.898870e+05     0.721
# Algeria                 1.921982e+06     0.667
# Angola                  1.885300e+05     0.445
# Antigua and Barbuda     2.913262e+04       NaN
# Argentina               6.854530e+06     0.765
# Armenia                 1.610541e+05     0.689
# Aruba                   2.565298e+04       NaN
# Australia               1.285422e+07     0.918
# Austria                 4.774674e+06     0.860
# Azerbaijan              6.896408e+05       NaN
# Bahamas                 7.983950e+04     0.766
# Bahrain                 1.544110e+05     0.795
# Bangladesh              3.397129e+05     0.462
# Barbados                1.516733e+05     0.787
# Belarus                          NaN     0.723
# Belgium                 6.228738e+06     0.873
# Belize                  2.587603e+04     0.689
# Benin                   9.702745e+04     0.409
# Bermuda                 4.197120e+04       NaN
# Bhutan                  2.536371e+04       NaN
# Bolivia                 4.781491e+05     0.649
# Bosnia and Herzegovina  8.063628e+05     0.717
# Botswana                6.119485e+04     0.601
# Brazil                  3.909957e+07     0.692
# Brunei                  1.324179e+05     0.830
# Bulgaria                1.545501e+06     0.749
# Burkina Faso            6.672063e+04     0.302
# Burundi                 3.931308e+04     0.267
# Cambodia                4.238649e+04     0.491
# ...                              ...       ...
# Sudan                   4.962770e+05     0.383
# Suriname                3.197023e+04     0.659
# Swaziland               4.084806e+04     0.493
# Sweden                  7.659593e+06     0.896
# Switzerland             5.197920e+06     0.890
# Syria                   1.044003e+06     0.621
# Tajikistan              1.927518e+04     0.575
# Thailand                1.002212e+07     0.656
# Macedonia, FYR          5.390798e+05     0.704
# Togo                    2.163218e+05     0.419
# Tonga                   4.953229e+03     0.696
# Trinidad and Tobago     3.811556e+05     0.728
# Tunisia                 9.570232e+05     0.667
# Turkey                  1.053494e+07     0.671
# Turkmenistan            4.734814e+04     0.654
# Tuvalu                           NaN       NaN
# Uganda                  4.953300e+05     0.401
# Ukraine                 1.759537e+06     0.712
# United Arab Emirates    1.627740e+06     0.807
# United Kingdom          4.214191e+07     0.855
# Tanzania                1.669734e+06     0.420
# United States           2.017430e+08     0.902
# Virgin Islands (U.S.)   2.990457e+04       NaN
# Uruguay                 6.674359e+05     0.748
# Uzbekistan              8.675544e+05     0.611
# Vanuatu                 1.073236e+04       NaN
# Venezuela               3.347147e+06     0.692
# Vietnam                 1.059467e+07     0.561
# Zambia                  3.268783e+05     0.394
# Zimbabwe                1.007663e+06     0.347
#
# [183 rows x 6 columns]

# %%
def reta(dados_x, dados_y):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)

    fig = plt.figure(figsize=(8, 6))
    plt.scatter(dados_x, dados_y, c='red', alpha=0.8)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color='blue')

    plt.tight_layout()
    plt.show()
